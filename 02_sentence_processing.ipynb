# %%
import nltk

# скачиваем необходимые пакеты
nltk.download("punkt")
nltk.download("punkt_tab")
from nltk.tokenize import sent_tokenize

sentences = []
for t in texts:
    sentences.extend(sent_tokenize(t))

len(sentences)


import re

# функция удаления знаков препинания (оставляем только буквы и пробелы)
def remove_punctuation(sentence):
    return re.sub(r"[.,!?]", "", sentence)

# создаём список "входов" для модели
inputs_no_punct = [remove_punctuation(s) for s in sentences]

# посмотрим первые 5 примеров
for orig, no_punct in zip(sentences[:5], inputs_no_punct[:5]):
    print("Оригинал:   ", orig)
    print("Без пункт.: ", no_punct)
    print("-"*40)
